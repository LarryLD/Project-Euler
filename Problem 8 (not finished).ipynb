# %%
large_num = ...

def find_largest_product(x, num):
    remaining = list(filter((lambda x: len(x) >= 13), str(x).split('0')))
    length_and_seg = [(len(elem), elem) for elem in remaining]
    
    candidates = []
    for elem in length_and_seg:
        for i in range(elem[0] - num + 1):
            
    
    return length_and_seg

def trunc_int(x, num):
    

find_largest_product(large_num, 123)
# Out:
# [(13, '7316717653133'),
#  (43, '6249192251196744265747423553491949349698352'),
#  (13, '6326239578318'),
#  (20, '18694788518438586156'),
#  (16, '7891129494954595'),
#  (17, '17379583319528532'),
#  (15, '698747158523863'),
#  (15, '435576689664895'),
#  (19, '4452445231617318564'),
#  (30, '987111217223831136222989342338'),
#  (17, '81353362766142828'),
#  (17, '64444866452387493'),
#  (19, '1724271218839987979'),
#  (13, '9377665727333'),
#  (15, '594752243525849'),
#  (33, '632441572215539753697817977846174'),
#  (35, '86256932197846862248283972241375657'),
#  (17, '79729686524145351'),
#  (40, '6585412275886668811642717147992444292823'),
#  (69, '863465674813919123162824586178664583591245665294765456828489128831426'),
#  (17, '96245544436298123'),
#  (16, '9878799272442849'),
#  (15, '979191338754992'),
#  (27, '559357297257163626956188267')]

# %%
# Out:
# 12.3
